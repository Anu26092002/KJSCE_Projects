# %% [markdown]
# <div align="center" style = "font-family : Times New Roman; font-size : 20px"><B>K. J. Somaiya College of Engineering, Mumbai-77</B></div>
# <div align="center" style = "font-family : Time NewRoman; font-size : 15px">(Autonomous College Affiliated to University of Mumbai)</div>

# %% [markdown]
# <div align="center" style = "font-family : Time New Roman; font-size : 20px">Expolatory Data Analysis </div>

# %% [markdown]
# <div align="left" style = "font-family : Time New Roman; font-size : 20px; color : red; "><B>Name : Anurag Pulak Ghosh &nbsp;&nbsp;&nbsp;&nbsp; Roll No.: 1914019 &nbsp;&nbsp;&nbsp;&nbsp; Branch : Information Technology &nbsp;&nbsp;&nbsp;&nbsp; Class : A &nbsp; &nbsp;&nbsp;&nbsp; Batch : A2</div>

# %% [markdown]
# <h1 align="center" style = "font-family : Time New Roman; ">Experiment No.-4 : Applying and interpreting different plots</h1>

# %%
#importing all the required libraries.
import numpy as np #numpy and pandas for numerical analysis. 
import pandas as pd
import matplotlib.pyplot as mplt #matplotlib for data visualization.
from scipy.special import ndtri

# %%
#reading the dataset file.
fish_data = pd.read_csv("Fish.csv")

# %%
#Displaying the size of the dataset.
fish_data.shape
# Out:
# (159, 7)

# %%
#Displaying the info for the dataset.
fish_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
#displaying the dataset.
fish_data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
#Displaying the data types of the dataset.
fish_data.dtypes
# Out:
# Species     object
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object

# %%
#Displaying the top 5 rows of the dataset.
fish_data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
#Displaying the last 5 rows of the dataset.
fish_data.tail()
# Out:
#     Species  Weight  Length1  Length2  Length3  Height   Width
# 154   Smelt    12.2     11.5     12.2     13.4  2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5  2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8  2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2  2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2  2.9322  1.8792

# %% [markdown]
# <h1>1. Box Plot</h1>

# %%
weight_data = np.array(fish_data['Weight'])
length1_data = np.array(fish_data['Length1'])
length2_data = np.array(fish_data['Length2'])
length3_data = np.array(fish_data['Length3'])
height_data = np.array(fish_data['Height'])
width_data = np.array(fish_data['Width'])
data = [ length1_data, length2_data, length3_data, height_data, width_data]

fig = mplt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data, patch_artist = True, notch ='True', vert = 0)
 
colors = ['#00FF00','#FFCB00', '#CBCCAF', '#AAA000', '#00FFFF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# Changing the color and style of the wiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',linewidth = 1.5,linestyle =":")
    
# Changing color and linewidth of caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',linewidth = 2)
    
# Changing color and linewidth of medians
for median in bp['medians']:
    median.set(color ='red', linewidth = 2)
    
# Changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D', color ='#e7298a', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['Length1','Length2', 'Length3', 'Height', 'Width'])
 
# Adding title
mplt.title("Box Plot of 'Length1','Length2', 'Length3', 'Height', 'Width' attributes of fishes in the dataset")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
mplt.show()

# %%
fig = mplt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(weight_data, patch_artist = True, notch ='True', vert = 0)
 
colors = ['#0000FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# Changing the color and style of the wiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',linewidth = 1.5,linestyle =":")
    
# Changing color and linewidth of caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',linewidth = 2)
    
# Changing color and linewidth of medians
for median in bp['medians']:
    median.set(color ='red', linewidth = 2)
    
# Changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D', color ='#e7298a', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['Weight'])
 
# Adding title
mplt.title("Box Plot of Fish Weight in the dataset")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
mplt.show()

# %% [markdown]
# <h1>2. Q-Q plot </h1>

# %%
data = fish_data.sort_values(by=['Weight'], ascending=True).reset_index()

# %%
data['Count'] = data.index + 1

# %%
data.head()
# Out:
#    index Species  Weight  Length1  Length2  Length3  Height   Width  Count
# 0     40   Roach     0.0     19.0     20.5     22.8  6.4752  3.3516      1
# 1     72   Perch     5.9      7.5      8.4      8.8  2.1120  1.4080      2
# 2    145   Smelt     6.7      9.3      9.8     10.8  1.7388  1.0476      3
# 3    147   Smelt     7.0     10.1     10.6     11.6  1.7284  1.1484      4
# 4    146   Smelt     7.5     10.0     10.5     11.6  1.9720  1.1600      5

# %%
n_rows = data.shape[0]
n_rows
# Out:
# 159

# %%
data['Percentile Area'] = (data['Count'])/n_rows
data
# Out:
#      index Species  Weight  Length1  Length2  Length3   Height   Width  Count  \
# 0       40   Roach     0.0     19.0     20.5     22.8   6.4752  3.3516      1
# 1       72   Perch     5.9      7.5      8.4      8.8   2.1120  1.4080      2
# 2      145   Smelt     6.7      9.3      9.8     10.8   1.7388  1.0476      3
# 3      147   Smelt     7.0     10.1     10.6     11.6   1.7284  1.1484      4
# 4      146   Smelt     7.5     10.0     10.5     11.6   1.9720  1.1600      5
# ..     ...     ...     ...      ...      ...      ...      ...     ...    ...
# 154    125   Perch  1100.0     40.1     43.0     45.5  12.5125  7.4165    155
# 155    141    Pike  1250.0     52.0     56.0     59.7  10.6863  6.9849    156
# 156    143    Pike  1550.0     56.0     60.0     64.0   9.6000  6.1440    157
# 157    142    Pike  1600.0     56.0     60.0     64.0   9.6000  6.1440    158
# 158    144    Pike  1650.0     59.0     63.4     68.0  10.8120  7.4800    159
#
#      Percentile Area
# ...

# %%
data['Z Theoritical'] = ndtri(data['Percentile Area'])
data
# Out:
#      index Species  Weight  Length1  Length2  Length3   Height   Width  Count  \
# 0       40   Roach     0.0     19.0     20.5     22.8   6.4752  3.3516      1
# 1       72   Perch     5.9      7.5      8.4      8.8   2.1120  1.4080      2
# 2      145   Smelt     6.7      9.3      9.8     10.8   1.7388  1.0476      3
# 3      147   Smelt     7.0     10.1     10.6     11.6   1.7284  1.1484      4
# 4      146   Smelt     7.5     10.0     10.5     11.6   1.9720  1.1600      5
# ..     ...     ...     ...      ...      ...      ...      ...     ...    ...
# 154    125   Perch  1100.0     40.1     43.0     45.5  12.5125  7.4165    155
# 155    141    Pike  1250.0     52.0     56.0     59.7  10.6863  6.9849    156
# 156    143    Pike  1550.0     56.0     60.0     64.0   9.6000  6.1440    157
# 157    142    Pike  1600.0     56.0     60.0     64.0   9.6000  6.1440    158
# 158    144    Pike  1650.0     59.0     63.4     68.0  10.8120  7.4800    159
#
# ...

# %%
data['Z Actual'] = (data['Weight']-data['Weight'].mean())/data['Weight'].std(ddof=0)
data
# Out:
#      index Species  Weight  Length1  Length2  Length3   Height   Width  Count  \
# 0       40   Roach     0.0     19.0     20.5     22.8   6.4752  3.3516      1
# 1       72   Perch     5.9      7.5      8.4      8.8   2.1120  1.4080      2
# 2      145   Smelt     6.7      9.3      9.8     10.8   1.7388  1.0476      3
# 3      147   Smelt     7.0     10.1     10.6     11.6   1.7284  1.1484      4
# 4      146   Smelt     7.5     10.0     10.5     11.6   1.9720  1.1600      5
# ..     ...     ...     ...      ...      ...      ...      ...     ...    ...
# 154    125   Perch  1100.0     40.1     43.0     45.5  12.5125  7.4165    155
# 155    141    Pike  1250.0     52.0     56.0     59.7  10.6863  6.9849    156
# 156    143    Pike  1550.0     56.0     60.0     64.0   9.6000  6.1440    157
# 157    142    Pike  1600.0     56.0     60.0     64.0   9.6000  6.1440    158
# 158    144    Pike  1650.0     59.0     63.4     68.0  10.8120  7.4800    159
#
# ...

# %%
mplt.scatter(data['Z Actual'],data['Z Theoritical'])
mplt.plot([-2,-1,0,1,2,3],[-2,-1,0,1,2,3], color="r")
mplt.xlabel('Data Quantiles') 
mplt.ylabel('Normal Quantiles') 

# displaying the title
mplt.title("Quantile-Quantile plot for distribution of fish weight")
  
mplt.show()

# %% [markdown]
# <h1>3. Histogram</h1>

# %%
n_bins = 10
fig, axs = mplt.subplots(1, 1,figsize =(10, 7),tight_layout = True)
axs.hist(fish_data['Weight'], bins = n_bins)

mplt.xlabel('Weight of fishes (in kg)') 
mplt.ylabel('Number of fishes') 

# displaying the title
mplt.title("Histogram for distribution of fish weight")
# Show plot
mplt.show()

# %%
n_bins = 10
fig, axs = mplt.subplots(1, 1,figsize =(10, 7),tight_layout = True)
axs.hist(fish_data['Height'], bins = n_bins)

mplt.xlabel('Height of fishes (in cm)') 
mplt.ylabel('Number of fishes') 

# displaying the title
mplt.title("Histogram for distribution of fish height")
# Show plot
mplt.show()

# %%
n_bins = 10
fig, axs = mplt.subplots(1, 1,figsize =(10, 7),tight_layout = True)
axs.hist(fish_data['Length1'], bins = n_bins)

mplt.xlabel('Length1 of fishes (in cm)') 
mplt.ylabel('Number of fishes') 

# displaying the title
mplt.title("Histogram for distribution of fish length 1")
# Show plot
mplt.show()

# %%
n_bins = 10
fig, axs = mplt.subplots(1, 1,figsize =(10, 7),tight_layout = True)
axs.hist(fish_data['Length2'], bins = n_bins)

mplt.xlabel('Length2 of fishes (in cm)') 
mplt.ylabel('Number of fishes') 

# displaying the title
mplt.title("Histogram for distribution of fish length 2")
# Show plot
mplt.show()

# %% [markdown]
# <h1>4. Scatter Plot </h1>

# %%
#Plotting the scatter plot for Weight and Height of the dataset.
mplt.scatter(fish_data["Weight"],fish_data["Height"],color='b')
mplt.xlabel('Weight of different fish species')
mplt.ylabel('Height of different fish species')
mplt.title("Scatter plot of weight and height of different fish species")
mplt.show()

# %%
#Plotting the scatter plot for Weight and Width of the dataset.
mplt.scatter(fish_data["Weight"],fish_data["Width"],color='b')
mplt.xlabel('Weight of different fish species')
mplt.ylabel('Width of different fish species')
mplt.title("Scatter plot of weight and width of different fish species")
mplt.show()

# %%
#Plotting the scatter plot for Weight and Width of the dataset.
mplt.scatter(fish_data["Weight"],fish_data["Width"],color='b')
mplt.xlabel('Weight of different fish species')
mplt.ylabel('Width of different fish species')
mplt.title("Scatter plot of height and width of different fish species")
mplt.show()
